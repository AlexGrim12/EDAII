# %% [markdown]
# # Practica 6
#
# ### Gutiérrez Grimaldo Alejandro

# %% [markdown]
# ## Actividad No. 1

# %%
# Gutierrez Grimaldo Alejandro

class Vertice:
    def __init__(self, n):
        self.nombre = n
        self.vecinos = []
        self.d=0
        self.f=0
        self.pred = -1
        self.color = "white"
    def agregarVecino(self, v):
        if v not in self.vecinos:
            self.vecinos.append(v)
            self.vecinos.sort()
    
class Grafo:
    def __init__(self, tipo):
        self.vertices = {}
        self.tipo = tipo
        self.oredenT = []
        
    def agregarVertice(self, v):
        if v not in self.vertices:
            self.vertices[v] = Vertice(v)
            
    def agregarArista(self, u, v):
        if u in self.vertices and v in self.vertices:
            if self.tipo == 1:
                self.vertices[u].agregarVecino(v)
            else:
                self.vertices[u].agregarVecino(v)
                self.vertices[v].agregarVecino(u)
    
    def dfs(self):
        for u in self.vertices:
            global tiempo
            tiempo = 0
            for u in sorted(list(self.vertices.keys())):
                if self.vertices[u].color == "white":
                    self.dfsVisitar(self.vertices[u])
                    
    def dfsVisitar(self, vert):
        global tiempo
        tiempo += 1
        vert.d=tiempo
        vert.color="gris"
        for v in vert.vecinos:
            if self.vertices[v].color == "white":
                self.vertices[v].pred = vert
                self.dfsVisitar(self.vertices[v])
        vert.color = "black"
        tiempo += 1
        vert.f = tiempo
        self.oredenT.insert(0, vert.nombre)
    
    def imprimirGrafo(self):
        for v in self.vertices:
            print(v, self.vertices[v].vecinos)
        
    def imprimirTiempo(self):
        print()
        for v in self.vertices:
            print("vertice: ",v,"\nDescubrimiento/Termino", self.vertices[v].d,"/", self.vertices[v].f)
        
g = Grafo(1)

# Agregar los vertices
g.agregarVertice('u')
g.agregarVertice('v')
g.agregarVertice('w')
g.agregarVertice('x')
g.agregarVertice('y')
g.agregarVertice('z')

# Agregar las aristas
g.agregarArista('u', 'v')
g.agregarArista('u', 'x')
g.agregarArista('x', 'v')
g.agregarArista('v', 'y')
g.agregarArista('y', 'x')
g.agregarArista('w', 'y')
g.agregarArista('w', 'z')
g.agregarArista('z', 'z')


# Imprimir el grafo
g.imprimirGrafo()

# Implementar el algoritmo DFS y mostrar el tiempo de descubrimiento y termino
g.dfs()
g.imprimirTiempo()
# Out:
# u ['v', 'x']
# v ['y']
# w ['y', 'z']
# x ['v']
# y ['x']
# z ['z']
#
# vertice:  u
# Descubrimiento/Termino 1 / 8
# vertice:  v
# Descubrimiento/Termino 2 / 7
# vertice:  w
# Descubrimiento/Termino 9 / 12
# vertice:  x
# Descubrimiento/Termino 4 / 5
# vertice:  y
# Descubrimiento/Termino 3 / 6
# vertice:  z
# Descubrimiento/Termino 10 / 11

# %% [markdown]
# ## Actividad No.2

# %%
# Gutierrez Grimaldo Alejandro

class Vertice:
    def __init__(self, n):
        self.nombre = n
        self.vecinos = []
        self.d=0
        self.f=0
        self.pred = -1
        self.color = "white"
    def agregarVecino(self, v):
        if v not in self.vecinos:
            self.vecinos.append(v)
            self.vecinos.sort()
    
class Grafo:
    def __init__(self, tipo):
        self.vertices = {}
        self.tipo = tipo
        self.oredenT = []
        
    def agregarVertice(self, v):
        if v not in self.vertices:
            self.vertices[v] = Vertice(v)
            
    def agregarArista(self, u, v):
        if u in self.vertices and v in self.vertices:
            if self.tipo == 1:
                self.vertices[u].agregarVecino(v)
            else:
                self.vertices[u].agregarVecino(v)
                self.vertices[v].agregarVecino(u)
    
    def dfs(self):
        for u in self.vertices:
            global tiempo
            tiempo = 0
            for u in sorted(list(self.vertices.keys())):
                if self.vertices[u].color == "white":
                    self.dfsVisitar(self.vertices[u])
                    
    def dfsVisitar(self, vert):
        global tiempo
        tiempo += 1
        vert.d=tiempo
        vert.color="gris"
        for v in vert.vecinos:
            if self.vertices[v].color == "white":
                self.vertices[v].pred = vert
                self.dfsVisitar(self.vertices[v])
        vert.color = "black"
        tiempo += 1
        vert.f = tiempo
        self.oredenT.insert(0, vert.nombre)
    
    def imprimirGrafo(self):
        for v in self.vertices:
            print(v, self.vertices[v].vecinos)
            
    def imprimirOrdenT(self):
        print("\nEl orden topologico es: ", self.oredenT)
        
    def imprimirTiempo(self):
        print()
        for v in self.vertices:
            print("vertice: ",v,"\nDescubrimiento/Termino", self.vertices[v].d,"/", self.vertices[v].f)
        
g = Grafo(1)

# Agregar los vertices
g.agregarVertice('u')
g.agregarVertice('v')
g.agregarVertice('w')
g.agregarVertice('x')
g.agregarVertice('y')
g.agregarVertice('z')

# Agregar las aristas
g.agregarArista('u', 'v')
g.agregarArista('u', 'x')
g.agregarArista('x', 'v')
g.agregarArista('v', 'y')
g.agregarArista('y', 'x')
g.agregarArista('w', 'y')
g.agregarArista('w', 'z')
g.agregarArista('z', 'z')


# Imprimir el grafo
g.imprimirGrafo()

# Implementar el algoritmo DFS
g.dfs()

# Imprimir el tiempo de descubrimiento y finalizacion
g.imprimirTiempo()

# Imprimir el orden topologico
g.imprimirOrdenT()
# Out:
# u ['v', 'x']
# v ['y']
# w ['y', 'z']
# x ['v']
# y ['x']
# z ['z']
#
# vertice:  u
# Descubrimiento/Termino 1 / 8
# vertice:  v
# Descubrimiento/Termino 2 / 7
# vertice:  w
# Descubrimiento/Termino 9 / 12
# vertice:  x
# Descubrimiento/Termino 4 / 5
# vertice:  y
# Descubrimiento/Termino 3 / 6
# vertice:  z
# Descubrimiento/Termino 10 / 11
#
# El orden topologico es:  ['w', 'z', 'u', 'v', 'y', 'x']
