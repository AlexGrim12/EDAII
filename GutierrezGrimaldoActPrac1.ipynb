# %% [markdown]
# # Practica 1
#
# ### Gutiérrez Grimaldo Alejandro

# %% [markdown]
# ## Actividad No. 1

# %%
#Gutiérrez Grimaldo Alejandro

def bubbleSort(lista):
    print("Lista original")
    print([lista], end="\n\n")
    for i in range(1, len(lista)):
        print(f"Pasada {i} \n")
        for j in range(len(lista)-1):
            if lista[j]>lista[j+1]:
                temp = lista[j]
                lista[j] = lista[j+1]
                lista[j+1] = temp
            print(lista)
        print()
lista=[8,20,2,39,11,34,22,5,2,0]
bubbleSort(lista)
# Out:
# Lista original
# [[8, 20, 2, 39, 11, 34, 22, 5, 2, 0]]
#
# Pasada 1
#
# [8, 20, 2, 39, 11, 34, 22, 5, 2, 0]
# [8, 2, 20, 39, 11, 34, 22, 5, 2, 0]
# [8, 2, 20, 39, 11, 34, 22, 5, 2, 0]
# [8, 2, 20, 11, 39, 34, 22, 5, 2, 0]
# [8, 2, 20, 11, 34, 39, 22, 5, 2, 0]
# [8, 2, 20, 11, 34, 22, 39, 5, 2, 0]
# [8, 2, 20, 11, 34, 22, 5, 39, 2, 0]
# [8, 2, 20, 11, 34, 22, 5, 2, 39, 0]
# [8, 2, 20, 11, 34, 22, 5, 2, 0, 39]
#
# Pasada 2
#
# [2, 8, 20, 11, 34, 22, 5, 2, 0, 39]
# [2, 8, 20, 11, 34, 22, 5, 2, 0, 39]
# [2, 8, 11, 20, 34, 22, 5, 2, 0, 39]
# [2, 8, 11, 20, 34, 22, 5, 2, 0, 39]
# [2, 8, 11, 20, 22, 34, 5, 2, 0, 39]
# [2, 8, 11, 20, 22, 5, 34, 2, 0, 39]
# [2, 8, 11, 20, 22, 5, 2, 34, 0, 39]
# [2, 8, 11, 20, 22, 5, 2, 0, 34, 39]
# [2, 8, 11, 20, 22, 5, 2, 0, 34, 39]
#
# Pasada 3
#
# [2, 8, 11, 20, 22, 5, 2, 0, 34, 39]
# [2, 8, 11, 20, 22, 5, 2, 0, 34, 39]
# [2, 8, 11, 20, 22, 5, 2, 0, 34, 39]
# [2, 8, 11, 20, 22, 5, 2, 0, 34, 39]
# [2, 8, 11, 20, 5, 22, 2, 0, 34, 39]
# [2, 8, 11, 20, 5, 2, 22, 0, 34, 39]
# [2, 8, 11, 20, 5, 2, 0, 22, 34, 39]
# [2, 8, 11, 20, 5, 2, 0, 22, 34, 39]
# [2, 8, 11, 20, 5, 2, 0, 22, 34, 39]
#
# Pasada 4
#
# [2, 8, 11, 20, 5, 2, 0, 22, 34, 39]
# [2, 8, 11, 20, 5, 2, 0, 22, 34, 39]
# [2, 8, 11, 20, 5, 2, 0, 22, 34, 39]
# [2, 8, 11, 5, 20, 2, 0, 22, 34, 39]
# [2, 8, 11, 5, 2, 20, 0, 22, 34, 39]
# [2, 8, 11, 5, 2, 0, 20, 22, 34, 39]
# [2, 8, 11, 5, 2, 0, 20, 22, 34, 39]
# [2, 8, 11, 5, 2, 0, 20, 22, 34, 39]
# [2, 8, 11, 5, 2, 0, 20, 22, 34, 39]
#
# Pasada 5
#
# [2, 8, 11, 5, 2, 0, 20, 22, 34, 39]
# [2, 8, 11, 5, 2, 0, 20, 22, 34, 39]
# [2, 8, 5, 11, 2, 0, 20, 22, 34, 39]
# [2, 8, 5, 2, 11, 0, 20, 22, 34, 39]
# [2, 8, 5, 2, 0, 11, 20, 22, 34, 39]
# [2, 8, 5, 2, 0, 11, 20, 22, 34, 39]
# [2, 8, 5, 2, 0, 11, 20, 22, 34, 39]
# [2, 8, 5, 2, 0, 11, 20, 22, 34, 39]
# [2, 8, 5, 2, 0, 11, 20, 22, 34, 39]
#
# Pasada 6
#
# [2, 8, 5, 2, 0, 11, 20, 22, 34, 39]
# [2, 5, 8, 2, 0, 11, 20, 22, 34, 39]
# [2, 5, 2, 8, 0, 11, 20, 22, 34, 39]
# [2, 5, 2, 0, 8, 11, 20, 22, 34, 39]
# [2, 5, 2, 0, 8, 11, 20, 22, 34, 39]
# [2, 5, 2, 0, 8, 11, 20, 22, 34, 39]
# [2, 5, 2, 0, 8, 11, 20, 22, 34, 39]
# [2, 5, 2, 0, 8, 11, 20, 22, 34, 39]
# [2, 5, 2, 0, 8, 11, 20, 22, 34, 39]
#
# Pasada 7
#
# [2, 5, 2, 0, 8, 11, 20, 22, 34, 39]
# [2, 2, 5, 0, 8, 11, 20, 22, 34, 39]
# [2, 2, 0, 5, 8, 11, 20, 22, 34, 39]
# [2, 2, 0, 5, 8, 11, 20, 22, 34, 39]
# [2, 2, 0, 5, 8, 11, 20, 22, 34, 39]
# [2, 2, 0, 5, 8, 11, 20, 22, 34, 39]
# [2, 2, 0, 5, 8, 11, 20, 22, 34, 39]
# [2, 2, 0, 5, 8, 11, 20, 22, 34, 39]
# [2, 2, 0, 5, 8, 11, 20, 22, 34, 39]
#
# Pasada 8
#
# [2, 2, 0, 5, 8, 11, 20, 22, 34, 39]
# [2, 0, 2, 5, 8, 11, 20, 22, 34, 39]
# [2, 0, 2, 5, 8, 11, 20, 22, 34, 39]
# [2, 0, 2, 5, 8, 11, 20, 22, 34, 39]
# [2, 0, 2, 5, 8, 11, 20, 22, 34, 39]
# [2, 0, 2, 5, 8, 11, 20, 22, 34, 39]
# [2, 0, 2, 5, 8, 11, 20, 22, 34, 39]
# [2, 0, 2, 5, 8, 11, 20, 22, 34, 39]
# [2, 0, 2, 5, 8, 11, 20, 22, 34, 39]
#
# Pasada 9
#
# [0, 2, 2, 5, 8, 11, 20, 22, 34, 39]
# [0, 2, 2, 5, 8, 11, 20, 22, 34, 39]
# [0, 2, 2, 5, 8, 11, 20, 22, 34, 39]
# [0, 2, 2, 5, 8, 11, 20, 22, 34, 39]
# [0, 2, 2, 5, 8, 11, 20, 22, 34, 39]
# [0, 2, 2, 5, 8, 11, 20, 22, 34, 39]
# [0, 2, 2, 5, 8, 11, 20, 22, 34, 39]
# [0, 2, 2, 5, 8, 11, 20, 22, 34, 39]
# [0, 2, 2, 5, 8, 11, 20, 22, 34, 39]

# %% [markdown]
# ## Actividad No. 2

# %%
#Gutiérrez Grimaldo Alejandro

def bubbleSortMejorado(lista):
    flag = True
    i = 1
    print("Lista original")
    print([lista], end="\n\n")
    while i < len(lista)-1 and flag:
        print(f"Pasada {i} \n")
        flag = False
        for j in range(len(lista)-1-i):
            if(lista[j]>lista[j+1]):
                flag = True
                temp = lista[j]
                lista[j] = lista[j+1]
                lista[j+1] = temp
            print(lista)
        print()
        i = i + 1
lista=[8,20,2,39,11,34,22,5,2,0]
bubbleSortMejorado(lista)
# Out:
# Lista original
# [[8, 20, 2, 39, 11, 34, 22, 5, 2, 0]]
#
# Pasada 1
#
# [8, 20, 2, 39, 11, 34, 22, 5, 2, 0]
# [8, 2, 20, 39, 11, 34, 22, 5, 2, 0]
# [8, 2, 20, 39, 11, 34, 22, 5, 2, 0]
# [8, 2, 20, 11, 39, 34, 22, 5, 2, 0]
# [8, 2, 20, 11, 34, 39, 22, 5, 2, 0]
# [8, 2, 20, 11, 34, 22, 39, 5, 2, 0]
# [8, 2, 20, 11, 34, 22, 5, 39, 2, 0]
# [8, 2, 20, 11, 34, 22, 5, 2, 39, 0]
#
# Pasada 2
#
# [2, 8, 20, 11, 34, 22, 5, 2, 39, 0]
# [2, 8, 20, 11, 34, 22, 5, 2, 39, 0]
# [2, 8, 11, 20, 34, 22, 5, 2, 39, 0]
# [2, 8, 11, 20, 34, 22, 5, 2, 39, 0]
# [2, 8, 11, 20, 22, 34, 5, 2, 39, 0]
# [2, 8, 11, 20, 22, 5, 34, 2, 39, 0]
# [2, 8, 11, 20, 22, 5, 2, 34, 39, 0]
#
# Pasada 3
#
# [2, 8, 11, 20, 22, 5, 2, 34, 39, 0]
# [2, 8, 11, 20, 22, 5, 2, 34, 39, 0]
# [2, 8, 11, 20, 22, 5, 2, 34, 39, 0]
# [2, 8, 11, 20, 22, 5, 2, 34, 39, 0]
# [2, 8, 11, 20, 5, 22, 2, 34, 39, 0]
# [2, 8, 11, 20, 5, 2, 22, 34, 39, 0]
#
# Pasada 4
#
# [2, 8, 11, 20, 5, 2, 22, 34, 39, 0]
# [2, 8, 11, 20, 5, 2, 22, 34, 39, 0]
# [2, 8, 11, 20, 5, 2, 22, 34, 39, 0]
# [2, 8, 11, 5, 20, 2, 22, 34, 39, 0]
# [2, 8, 11, 5, 2, 20, 22, 34, 39, 0]
#
# Pasada 5
#
# [2, 8, 11, 5, 2, 20, 22, 34, 39, 0]
# [2, 8, 11, 5, 2, 20, 22, 34, 39, 0]
# [2, 8, 5, 11, 2, 20, 22, 34, 39, 0]
# [2, 8, 5, 2, 11, 20, 22, 34, 39, 0]
#
# Pasada 6
#
# [2, 8, 5, 2, 11, 20, 22, 34, 39, 0]
# [2, 5, 8, 2, 11, 20, 22, 34, 39, 0]
# [2, 5, 2, 8, 11, 20, 22, 34, 39, 0]
#
# Pasada 7
#
# [2, 5, 2, 8, 11, 20, 22, 34, 39, 0]
# [2, 2, 5, 8, 11, 20, 22, 34, 39, 0]
#
# Pasada 8
#
# [2, 2, 5, 8, 11, 20, 22, 34, 39, 0]

# %% [markdown]
# ## Actividad No. 3

# %%
#Gutiérrez Grimaldo Alejandro

def Merge(lista, p, q, r):
    izq = lista[p:(q + 1)]
    der = lista[q+1:(r + 1)]
    print("Izquierda:", izq)
    print("Derecha:", der)
    i = 0
    j = 0
    for k in range(p, r + 1):
        if(j >= len(der) or (i < len(izq) and izq[i] < der[j])):
            lista[k] = izq[i]
            i = i + 1
        else:
            lista[k] = der[j]
            j = j + 1
    print("Combinaciòn:", lista, end="\n\n")
            

def MergeS(lista, p, r):
    if(p < r):
        q = int((p + r)/2)
        MergeS(lista, p, q)
        MergeS(lista, q + 1, r)
        Merge(lista, p, q, r)


        
lista = [8,20,2,39,11,34,22,5,2,0]
print("Lista original")
print([lista], end="\n\n")
MergeS(lista, 0, 9)
# Out:
# Lista original
# [[8, 20, 2, 39, 11, 34, 22, 5, 2, 0]]
#
# Izquierda: [8]
# Derecha: [20]
# Combinaciòn: [8, 20, 2, 39, 11, 34, 22, 5, 2, 0]
#
# Izquierda: [8, 20]
# Derecha: [2]
# Combinaciòn: [2, 8, 20, 39, 11, 34, 22, 5, 2, 0]
#
# Izquierda: [39]
# Derecha: [11]
# Combinaciòn: [2, 8, 20, 11, 39, 34, 22, 5, 2, 0]
#
# Izquierda: [2, 8, 20]
# Derecha: [11, 39]
# Combinaciòn: [2, 8, 11, 20, 39, 34, 22, 5, 2, 0]
#
# Izquierda: [34]
# Derecha: [22]
# Combinaciòn: [2, 8, 11, 20, 39, 22, 34, 5, 2, 0]
#
# Izquierda: [22, 34]
# Derecha: [5]
# Combinaciòn: [2, 8, 11, 20, 39, 5, 22, 34, 2, 0]
#
# Izquierda: [2]
# Derecha: [0]
# Combinaciòn: [2, 8, 11, 20, 39, 5, 22, 34, 0, 2]
#
# Izquierda: [5, 22, 34]
# Derecha: [0, 2]
# Combinaciòn: [2, 8, 11, 20, 39, 0, 2, 5, 22, 34]
#
# Izquierda: [2, 8, 11, 20, 39]
# Derecha: [0, 2, 5, 22, 34]
# Combinaciòn: [0, 2, 2, 5, 8, 11, 20, 22, 34, 39]

# %% [markdown]
# ## Actividad No. 4

# %%
#Gutiérrez Grimaldo Alejandro

def InsertionSort(A, n):
    for j in range(1, n):
        llave = A[j]
        print(f"\nPasada {j} elemento a insertar {llave}")
        print(A)
        i = j-1
        while i >= 0 and A[i] > llave:
            A[i+1] = A[i]
            i = i-1
            print(A)
        A[i+1] = llave
        print(A)

lista = [12, 9, 3, 7, 14, 11]
InsertionSort(lista, len(lista))
# Out:
# Pasada 1 elemento a insertar 9
# [12, 9, 3, 7, 14, 11]
# [12, 12, 3, 7, 14, 11]
# [9, 12, 3, 7, 14, 11]
#
# Pasada 2 elemento a insertar 3
# [9, 12, 3, 7, 14, 11]
# [9, 12, 12, 7, 14, 11]
# [9, 9, 12, 7, 14, 11]
# [3, 9, 12, 7, 14, 11]
#
# Pasada 3 elemento a insertar 7
# [3, 9, 12, 7, 14, 11]
# [3, 9, 12, 12, 14, 11]
# [3, 9, 9, 12, 14, 11]
# [3, 7, 9, 12, 14, 11]
#
# Pasada 4 elemento a insertar 14
# [3, 7, 9, 12, 14, 11]
# [3, 7, 9, 12, 14, 11]
#
# Pasada 5 elemento a insertar 11
# [3, 7, 9, 12, 14, 11]
# [3, 7, 9, 12, 14, 14]
# [3, 7, 9, 12, 12, 14]
# [3, 7, 9, 11, 12, 14]

# %% [markdown]
# ## Actividad No. 5

# %%
#Gutiérrez Grimaldo Alejandro

def SelectionSort(A, n):
    print(f"Lista original {A}")
    for i in range(0, n):
        print(f"Pasada {i}\n{A}")
        min = i
        for j in range(i+1, n):
            if A[j] < A[min]:
                min = j
        print(f"Elemento minimo seleccionado {A[min]}")
        A[i], A[min] = A[min], A[i] 
        print(f"\t{A}")

lista = [12, 9, 3, 7, 14, 11]
SelectionSort(lista, len(lista))
# Out:
# Lista original [12, 9, 3, 7, 14, 11]
# Pasada 0
# [12, 9, 3, 7, 14, 11]
# Elemento minimo seleccionado 3
# 	[3, 9, 12, 7, 14, 11]
# Pasada 1
# [3, 9, 12, 7, 14, 11]
# Elemento minimo seleccionado 7
# 	[3, 7, 12, 9, 14, 11]
# Pasada 2
# [3, 7, 12, 9, 14, 11]
# Elemento minimo seleccionado 9
# 	[3, 7, 9, 12, 14, 11]
# Pasada 3
# [3, 7, 9, 12, 14, 11]
# Elemento minimo seleccionado 11
# 	[3, 7, 9, 11, 14, 12]
# Pasada 4
# [3, 7, 9, 11, 14, 12]
# Elemento minimo seleccionado 12
# 	[3, 7, 9, 11, 12, 14]
# Pasada 5
# [3, 7, 9, 11, 12, 14]
# Elemento minimo seleccionado 14
# 	[3, 7, 9, 11, 12, 14]

# %% [markdown]
# ## Actividad No. 6

# %%
#Gutiérrez Grimaldo Alejandro

import matplotlib.pyplot as plt
import random
from time import time

def MergeSort(C, p, r):
    if(p < r):
        q = int((p+r)/2)
        MergeSort(C, p, q)
        MergeSort(C, q+1, r)
        Merge(C, p, q, r)

def Merge(C, p, q, r):
	izq = C[p:(q+1)]
	der = C[q+1:(r+1)]
	i = 0
	j = 0
	for k in range(p, r+1):
		if(j >= len(der) or (i < len(izq) and izq[i] > der[j])):
			C[k] = izq[i]
			i = i+1
		else:
			C[k] = der[j]
			j = j+1

def bubbleSortM(B):
	bandera = True
	pasada = 0
	i = 1
	while pasada < len(B) and bandera:
		bandera = False
		for j in range(len(B)-1-pasada):
			if (B[j] > B[j+1]):
				bandera = True
				temp = B[j]
				B[j] = B[j+1]
				B[j+1] = temp
		pasada = pasada+1
		i = i +1

def InsertionSort(A, n):
    for j in range(1, n):
        llave = A[j]
        i = j-1
        while i >= 0 and A[i] > llave:
            A[i+1] = A[i]
            i = i-1
        A[i+1] = llave

def SelectionSort(A, n):
    for i in range(0, n):
        min = i
        for j in range(i+1, n):
            if A[j] < A[min]:
                min = j
        A[i], A[min] = A[min], A[i] 

def graficas():
    # Merge Sort
    TM = []
    nD = [k*100 for k in range(1, 31)]
    for k in nD:
        datosM = random.sample(range(1, 100000000), k)
        t0 = time()
        MergeSort(datosM, 0, len(datosM)-1)
        t1 = time()
        TM.append(round(t1-t0, 6))
    
    # Buble Sort Mejorado
    TB = []
    for k in nD:
        datosB = random.sample(range(1, 100000000), k)
        t0 = time()
        bubbleSortM(datosB)
        t1 = time()
        TB.append(round(t1-t0, 6))

    # Insertion Sort
    TI = []
    for k in nD:
        datosI = random.sample(range(1, 100000000), k)
        t0 = time()
        InsertionSort(datosI, len(datosI))
        t1 = time()
        TI.append(round(t1-t0, 6))
    
    # Selection Sort
    TS = []
    for k in nD:
        datosS = random.sample(range(1, 100000000), k)
        t0 = time()
        SelectionSort(datosS, len(datosS))
        t1 = time()
        TS.append(round(t1-t0, 6))

    # Mostrar todas las graficas en una sola ventana
    fig, ax = plt.subplots()

    ax.plot(nD, TM, label="Merge Sort", marker = "*")
    ax.plot(nD, TB, label="Bubble Sort Mejorado", marker = "*")
    ax.plot(nD, TI, label="Insertion Sort", marker = "*")
    ax.plot(nD, TS, label="Selection Sort", marker = "*")

    ax.set_xlabel("n Datos")
    ax.set_ylabel("Tiempo")
    ax.set_title("n vs t(n)")
    
    ax.grid(True)
    ax.legend(loc=2)
    plt.show()

graficas()
# Out:
# Matplotlib is building the font cache; this may take a moment.
